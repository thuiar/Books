# %%
import numpy as np
a = np.load('labels.npy')
print(len(a))
# Out:
# 150

# %%
import csv
import random
import numpy as np
import os

with open('td.tsv', "r", encoding="utf-8") as f:
    reader = csv.reader(f,delimiter = "\t")
    texts = []
    labels = []
    for row in reader:
        text = row[0]
        label = row[1]
        if text == 'text':
            continue
        texts.append(text)
        labels.append(label)

num_all = len(labels)
label_list = list(np.unique(np.array(labels)))
labels = np.array(labels)
res_ids = []
for label in label_list:
    num = int(len(labels[labels == label]) / 2)
    pos = list(np.where(labels == label)[0])
    res_ids.extend(random.sample(pos, num))
    
random.shuffle(res_ids)

res_texts = []
res_labels = []
for idx in res_ids:
    res_texts.append(texts[idx])
    res_labels.append(labels[idx])
    

data_path = 'ori_dev.tsv'
with open(data_path, "w", encoding="utf-8") as f:
    writer = csv.writer(f, delimiter="\t")
    writer.writerow(['text', 'label'])
    for text, label in zip(res_texts, res_labels):
        writer.writerow([text, label])   

test_texts = []
test_labels = []
test_ids = []
for idx in range(num_all):
    if idx not in res_ids:
        test_ids.append(idx)
        
random.shuffle(test_ids)
for idx in test_ids:
    test_texts.append(texts[idx])
    test_labels.append(labels[idx])
    
data_path = 'ori_test.tsv'
with open(data_path, "w", encoding="utf-8") as f:
    writer = csv.writer(f, delimiter="\t")
    writer.writerow(['text', 'label'])
    for text, label in zip(test_texts, test_labels):
        writer.writerow([text, label])

# %%
x = ['1','2','3','3']
print(round(7 * 0.5))
# Out:
# 4

# %%
import csv
import random
import numpy as np
import os
texts = []
labels = []
with open('train.tsv', "r", encoding="utf-8") as f:
    reader = csv.reader(f,delimiter = "\t")

    for row in reader:
        text = row[0]
        label = row[1]
        if text == 'text':
            continue
        texts.append(text)
        labels.append(label)
        
with open('dev.tsv', "r", encoding="utf-8") as f:
    reader = csv.reader(f,delimiter = "\t")

    for row in reader:
        text = row[0]
        label = row[1]
        if text == 'text':
            continue
        texts.append(text)
        labels.append(label)
        
with open('test.tsv', "r", encoding="utf-8") as f:
    reader = csv.reader(f,delimiter = "\t")

    for row in reader:
        text = row[0]
        label = row[1]
        if text == 'text':
            continue
        texts.append(text)
        labels.append(label)

with open('ori.tsv', "w", encoding="utf-8") as f:
    writer = csv.writer(f, delimiter="\t")
    writer.writerow(['text', 'label'])
    for text, label in zip(texts, labels):
        writer.writerow([text, label])  
        
print(len(texts))
print(len(labels))
print(len(np.unique(np.array(labels))))
# with open('ori.tsv', "r", encoding="utf-8") as f:
#     reader = csv.reader(f,delimiter = "\t")

#     for row in reader:
#         text = row[0]
#         label = row[1]
#         if text == 'text':
#             continue
#         texts.append(text)
#         labels.append(label)
# label_list = np.array(np.unique(np.array(labels)))
# labels = np.array(labels)
# print(len(label_list))
# print(len(labels))
# for label in label_list:
#     print(len(labels[labels == label]))
# Out:
# 23700
# 23700
# 151

# %%
x = np.load('labels.npy')
if 'oos' in x:
    print('a')
else:
    print('b')
# Out:
# b

# %%
import csv
import random
import numpy as np
import os
import pandas as pd

with open('ori.tsv', "r", encoding="utf-8") as f:
    reader = csv.reader(f,delimiter = "\t")
    texts = []
    labels = []
    for row in reader:
        text = row[0]
        label = row[1]
        if text == 'text':
            continue
        texts.append(text)
        labels.append(label)
        
df = pd.DataFrame(l, columns=['text', 'label'])
print(df[:10])
# random_state = 0                                   
# x = texts
# y = labels
                        
# from sklearn.model_selection import train_test_split#分割数据集
# X_train, X_test, y_train, y_test = train_test_split(x, y, stratify=yl, test_size=0.25)
# print(X_train)

# label_list = list(np.unique(np.array(labels)))
# print(len(label_list))
# res_ids = []
# for label in label_list:
#     if label == 'oos':
#     else:
#         num = len(labels[labels == label])
#         pos = list(np.where(labels == label)[0])
#         res_ids.extend(random.sample)
# num_all = len(labels)
# label_list = list(np.unique(np.array(labels)))
# labels = np.array(labels)
# res_ids = []
# for label in label_list:
#     num = int(len(labels[labels == label]) / 2)
#     pos = list(np.where(labels == label)[0])
#     res_ids.extend(random.sample(pos, num))
    
# random.shuffle(res_ids)

# res_texts = []
# res_labels = []
# for idx in res_ids:
#     res_texts.append(texts[idx])
#     res_labels.append(labels[idx])
    

# data_path = 'ori_dev.tsv'
# with open(data_path, "w", encoding="utf-8") as f:
#     writer = csv.writer(f, delimiter="\t")
#     writer.writerow(['text', 'label'])
#     for text, label in zip(res_texts, res_labels):
#         writer.writerow([text, label])   

# test_texts = []
# test_labels = []
# test_ids = []
# for idx in range(num_all):
#     if idx not in res_ids:
#         test_ids.append(idx)
        
# random.shuffle(test_ids)
# for idx in test_ids:
#     test_texts.append(texts[idx])
#     test_labels.append(labels[idx])
    
# data_path = 'ori_test.tsv'
# with open(data_path, "w", encoding="utf-8") as f:
#     writer = csv.writer(f, delimiter="\t")
#     writer.writerow(['text', 'label'])
#     for text, label in zip(test_texts, test_labels):
#         writer.writerow([text, label])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-55886f13e12b> in <module>
#      17         labels.append(label)
#      18
# ---> 19 l = [[x, y] for x in texts for y in labels]
#      20 df = pd.DataFrame(l, columns=['text', 'label'])
#      21 print(df[:10])
#
# <ipython-input-8-55886f13e12b> in <listcomp>(.0)
#      17         labels.append(label)
#      18
# ---> 19 l = [[x, y] for x in texts for y in labels]
#      20 df = pd.DataFrame(l, columns=['text', 'label'])
#      21 print(df[:10])
#
# KeyboardInterrupt:

# %%
import pandas as pd
train = pd.read_csv('original_data/train.tsv',sep="\t")
valid = pd.read_csv('original_data/dev.tsv',sep="\t")
test = pd.read_csv('original_data/test.tsv',sep="\t")

l1 = [[x,y] for x,y in zip(train['text'],train['label']) if y != 'oos']
l2 = [[x,y] for x,y in zip(valid['text'],valid['label']) if y != 'oos']
l3 = [[x,y] for x,y in zip(test['text'],test['label']) if y != 'oos']

df = pd.DataFrame(l1+l2+l3, columns=['text', 'label'])
df
# Out:
#                                                     text         label
# 0      what expression would i use to say i love you ...     translate
# 1      can you tell me how to say 'i do not speak muc...     translate
# 2      what is the equivalent of, 'life is good' in f...     translate
# 3      tell me how to say, 'it is a beautiful morning...     translate
# 4      if i were mongolian, how would i say that i am...     translate
# ...                                                  ...           ...
# 22495                         find out what song this is     what_song
# 22496         what number of days do i have for vacation   pto_balance
# 22497           i'd like you to check on my credit score  credit_score
# 22498               "which things are wanted to remember      reminder
# 22499       i'm going to paris, what plug type do i need     plug_type
#
# [22500 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
random_state = 0
df_train, df_dev_test = train_test_split(df, test_size=0.4, stratify=df.label, shuffle=True, random_state=random_state)
df_train.to_csv('train.tsv', sep='\t', index=False)
df_train
# Out:
#                                                     text  \
# 19039  walk me through the steps involved in changing...
# 8454            what kind of fuel does my vehicle run on
# 4210   i lost my luggage coming from new york city on...
# 20143                    what to do if i lost my luggage
# 7187    is it possible to use sausage instead of hot dog
# ...                                                  ...
# 17512        how can i claim my rewards for my visa card
# 18381  how do i get my paycheck into direct deposit a...
# 2262                                 it's either of them
# 8400             what kind of gasoline can this car take
# 7081             i need help since someone stole my card
#
#                          label
# 19039           oil_change_how
# 8454                  gas_type
# 4210              lost_luggage
# 20143             lost_luggage
# 7187   ingredient_substitution
# ...                        ...
# 17512           redeem_rewards
# 18381           direct_deposit
# 2262                     maybe
# 8400                  gas_type
# 7081          report_lost_card
#
# [13500 rows x 2 columns]

# %%
df_dev, df_test = train_test_split(df_dev_test, test_size=0.75, stratify=df_dev_test.label, shuffle=True, random_state=random_state)
df_dev.to_csv('dev.tsv', sep='\t', index=False)
df_dev
# Out:
#                                                     text                 label
# 5440                   give me the apr for my mastercard                   apr
# 2186   please inform me of the types of subjects are ...    what_can_i_ask_you
# 5436                               review of my card apr                   apr
# 10390  i want to report fraudulent activity on my vis...          report_fraud
# 4931   please put washing the dishes on my list of ta...      todo_list_update
# ...                                                  ...                   ...
# 8352     are there meeting rooms available between 10-11      schedule_meeting
# 22172  i'd like to cancel my reservation for 5 at hos...    cancel_reservation
# 6202   i need someone to look at my car because my ch...  schedule_maintenance
# 21074         if i travel abroad, do i need vaccinations              vaccines
# 17300                           how should i address you     what_is_your_name
#
# [2250 rows x 2 columns]

# %%
l1_oos = [[x,y] for x,y in zip(train['text'],train['label']) if y == 'oos']
l2_oos = [[x,y] for x,y in zip(valid['text'],valid['label']) if y == 'oos']
l3_oos = [[x,y] for x,y in zip(test['text'],test['label']) if y == 'oos']
df_oos = pd.DataFrame(l1_oos+l2_oos+l3_oos, columns=['text', 'label'])
df_oos
# Out:
#                                                    text label
# 0     which came first; greek mythology or roman myt...   oos
# 1     can you check how many steps i have walked in ...   oos
# 2                   tell me something about linkin park   oos
# 3               how many people still live on greenland   oos
# 4                 what is a good home remedy for a rash   oos
# ...                                                 ...   ...
# 1195  what time did i get the last text message i re...   oos
# 1196  send me live feed of the pre-game prediction s...   oos
# 1197  find out how many latin scholars there are at ...   oos
# 1198  tell me about the earthquake in california tha...   oos
# 1199                      what are apartment prices now   oos
#
# [1200 rows x 2 columns]

# %%
df_test = df_test.append(df_oos)
df_test
# Out:
#                                                     text               label
# 20460                       does cielo have good reviews  restaurant_reviews
# 2161                                   how can i use you  what_can_i_ask_you
# 18106     do you think our lives have purpose or meaning     meaning_of_life
# 15868                    play the song called baby shark          play_music
# 14284             i need to know how jumping a car works          jump_start
# ...                                                  ...                 ...
# 1195   what time did i get the last text message i re...                 oos
# 1196   send me live feed of the pre-game prediction s...                 oos
# 1197   find out how many latin scholars there are at ...                 oos
# 1198   tell me about the earthquake in california tha...                 oos
# 1199                       what are apartment prices now                 oos
#
# [7950 rows x 2 columns]

# %%
from sklearn.utils import shuffle
df_test = shuffle(df_test)
df_test.to_csv('test.tsv', sep='\t', index=False)
df_test
# Out:
#                                                  text               label
# 8964              can you please turn the volume to 4       change_volume
# 306                                 how is my driving                 oos
# 13380               tell me if you are a person or ai       are_you_a_bot
# 8080     what do the ratings say for black bear diner  restaurant_reviews
# 19893                       denver's timezone is what            timezone
# ...                                               ...                 ...
# 559        what are sigmund freud's most famous books                 oos
# 3346                    next song on the list, please           next_song
# 20461  are there any current travel alerts for brazil        travel_alert
# 13712      cancel the dinner reservation i made, okay  cancel_reservation
# 3117                show me what you think my name is           user_name
#
# [7950 rows x 2 columns]
